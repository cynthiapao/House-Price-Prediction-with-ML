# %%
# import data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('white')
sns.set_context('notebook', font_scale=1.5)
# %matplotlib inline

ames_train = pd.read_csv('Ames Housing dataset/train.csv')
ames_test = pd.read_csv('Ames Housing dataset/test.csv')

ames_train = pd.DataFrame(ames_train)

# %%
ames_train.head(10)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities    ...     PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN    NaN         NaN       0
# ...

# %%
ames_train.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %% [markdown]
# ## Imputing Missing Data
# - Drop columns where missing data occupy over 15%

# %%
missing = pd.DataFrame(ames_train.isnull().sum()/len(ames_train.index) * 100)
missing.columns = ['percent']
missing.loc[missing['percent'] > 15, 'column_select'] = True
missing.loc[missing['percent'] <= 15, 'column_select'] = False
missing.head()
# Out:
#                percent column_select
# Id            0.000000         False
# MSSubClass    0.000000         False
# MSZoning      0.000000         False
# LotFrontage  17.739726          True
# LotArea       0.000000         False

# %%
column_select = missing.index[missing['column_select'] == True].tolist()
column_select
# Out:
# ['LotFrontage', 'Alley', 'FireplaceQu', 'PoolQC', 'Fence', 'MiscFeature']

# %%
missing['column_select'].sum()
# Out:
# 6

# %%
ames_train.drop(column_select, inplace = True, axis = 1, errors = 'ignore')
ames_test.drop(column_select, inplace = True, axis = 1, errors = 'ignore')

ames_train.head(5)
# Out:
#    Id  MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# 0   1          60       RL     8450   Pave      Reg         Lvl    AllPub
# 1   2          20       RL     9600   Pave      Reg         Lvl    AllPub
# 2   3          60       RL    11250   Pave      IR1         Lvl    AllPub
# 3   4          70       RL     9550   Pave      IR1         Lvl    AllPub
# 4   5          60       RL    14260   Pave      IR1         Lvl    AllPub
#
#   LotConfig LandSlope    ...    EnclosedPorch 3SsnPorch ScreenPorch PoolArea  \
# 0    Inside       Gtl    ...                0         0           0        0
# 1       FR2       Gtl    ...                0         0           0        0
# 2    Inside       Gtl    ...                0         0           0        0
# 3    Corner       Gtl    ...              272         0           0        0
# 4       FR2       Gtl    ...                0         0           0        0
#
# ...

# %%
ames_train.isnull().sum()
# Out:
# Id                0
# MSSubClass        0
# MSZoning          0
# LotArea           0
# Street            0
# LotShape          0
# LandContour       0
# Utilities         0
# LotConfig         0
# LandSlope         0
# Neighborhood      0
# Condition1        0
# Condition2        0
# BldgType          0
# HouseStyle        0
# OverallQual       0
# OverallCond       0
# YearBuilt         0
# YearRemodAdd      0
# RoofStyle         0
# RoofMatl          0
# Exterior1st       0
# Exterior2nd       0
# MasVnrType        8
# MasVnrArea        8
# ExterQual         0
# ExterCond         0
# Foundation        0
# BsmtQual         37
# BsmtCond         37
#                  ..
# BsmtFullBath      0
# BsmtHalfBath      0
# FullBath          0
# HalfBath          0
# BedroomAbvGr      0
# KitchenAbvGr      0
# KitchenQual       0
# TotRmsAbvGrd      0
# Functional        0
# Fireplaces        0
# GarageType       81
# GarageYrBlt      81
# GarageFinish     81
# GarageCars        0
# ...

# %% [markdown]
# How to deal with the left missing values?
#
# - Use mean values for numeric columns and the most frequent values for non-numeric columns

# %%
from sklearn.base import TransformerMixin
class MissingDataImputer(TransformerMixin):

    def __init__(self):
        """Impute missing values.

        If the column is of dtype Object, then impute with the most frequent value.
        If the column is not of dtype Object, then impute with the median.

        """
    def fit(self, X, y=None):
        
        for col in X:
            if X[col].dtype == np.dtype('O'):
                self.fill = X[col].value_counts().index[0]
            else:
                self.fill = X[col].median()
                
        return self

    def transform(self, X, y=None):
        return X.fillna(self.fill)

# %%
ames_traint = MissingDataImputer().fit_transform(ames_train)
ames_testt = MissingDataImputer().fit_transform(ames_test)

print('after...')
print(ames_testt.isnull().sum())
# Out:
# after...
# Id               0
# MSSubClass       0
# MSZoning         0
# LotArea          0
# Street           0
# LotShape         0
# LandContour      0
# Utilities        0
# LotConfig        0
# LandSlope        0
# Neighborhood     0
# Condition1       0
# Condition2       0
# BldgType         0
# HouseStyle       0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# RoofStyle        0
# RoofMatl         0
# Exterior1st      0
# Exterior2nd      0
# MasVnrType       0
# MasVnrArea       0
# ExterQual        0
# ExterCond        0
# Foundation       0
# BsmtQual         0
# BsmtCond         0
#                 ..
# GrLivArea        0
# BsmtFullBath     0
# BsmtHalfBath     0
# FullBath         0
# HalfBath         0
# BedroomAbvGr     0
# KitchenAbvGr     0
# KitchenQual      0
# TotRmsAbvGrd     0
# Functional       0
# Fireplaces       0
# GarageType       0
# GarageYrBlt      0
# GarageFinish     0
# GarageCars       0
# GarageArea       0
# ...

# %% [markdown]
# ## Transforming/Recoding Data

# %%
from sklearn.preprocessing import LabelBinarizer, StandardScaler

def cat_cols(df):
    return df.select_dtypes(include=['object'])

def num_cols(df):
    return df._get_numeric_data().drop(['Id'], axis = 1)

# for categorical variables: onehot encoding   
train_cat = pd.get_dummies(cat_cols(ames_traint))
test_cat = pd.get_dummies(cat_cols(ames_testt))

# for continuous variables: normalization
train_num = num_cols(ames_traint)
scaler = StandardScaler().fit(train_num)
train_norm = pd.DataFrame(scaler.transform(train_num), columns = train_num.columns.values)

## use statistics of train data to normalize test data
test_num = num_cols(ames_testt)
test_norm = pd.DataFrame(scaler.transform(test_num), columns = test_num.columns.values)
    
ames_traint = pd.concat([ames_traint['Id'], train_norm, train_cat], axis = 1)
ames_testt = pf.concat([ames_testt['Id'], test_norm, test_cat], axis = 1)
ames_testt.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-e4365d41b7d8> in <module>()
#      18 ## use statistics of train data to normalize test data
#      19 test_num = num_cols(ames_testt)
# ---> 20 test_norm = pd.DataFrame(scaler.transform(test_num), columns = test_num.columns.values)
#      21
#      22 ames_traint = pd.concat([ames_traint['Id'], train_norm, train_cat], axis = 1)
#
# C:\Users\Cynthia\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py in transform(self, X, y, copy)
#     658         else:
#     659             if self.with_mean:
# --> 660                 X -= self.mean_
#     661             if self.with_std:
#     662                 X /= self.scale_
#
# ValueError: operands could not be broadcast together with shapes (1459,25) (36,) (1459,25)

# %%
train_num.shape
# Out:
# (1460, 36)

# %%
test_num.shape
# Out:
# (1459, 25)

# %%
ames_train.shape
# Out:
# (1460, 75)

# %%
ames_test.shape
# Out:
# (1459, 74)

# %%
# correlation analysis with SalePrice
corr = pd.DataFrame(train_norm.corr(method = 'pearson')['SalePrice'])
corr.sort_values(['SalePrice'], ascending= False)
# Out:
#                SalePrice
# SalePrice       1.000000
# OverallQual     0.790982
# GrLivArea       0.708624
# GarageCars      0.640409
# GarageArea      0.623431
# TotalBsmtSF     0.613581
# 1stFlrSF        0.605852
# FullBath        0.560664
# TotRmsAbvGrd    0.533723
# YearBuilt       0.522897
# YearRemodAdd    0.507101
# Fireplaces      0.466929
# BsmtFinSF1      0.386420
# WoodDeckSF      0.324413
# 2ndFlrSF        0.319334
# OpenPorchSF     0.315856
# HalfBath        0.284108
# LotArea         0.263843
# BsmtFullBath    0.227122
# BsmtUnfSF       0.214479
# BedroomAbvGr    0.168213
# ScreenPorch     0.111447
# PoolArea        0.092404
# MasVnrArea      0.059060
# MoSold          0.046432
# 3SsnPorch       0.044584
# BsmtFinSF2     -0.011378
# BsmtHalfBath   -0.016844
# MiscVal        -0.021190
# LowQualFinSF   -0.025606
# YrSold         -0.028923
# OverallCond    -0.077856
# MSSubClass     -0.084284
# EnclosedPorch  -0.128578
# KitchenAbvGr   -0.135907
# GarageYrBlt    -0.236526

# %%
cmap = sns.cubehelix_palette(light = 0.95, as_cmap = True)
plt.figure(figsize = (10, 10))
sns.heatmap(abs(train_norm.corr(method = 'pearson')), vmin = 0, vmax = 1, square = True, cmap = cmap)

# %%
from xgboost import XGBClassifier
x_train = ames_traint.iloc[:, 1:-1].values
y_train = ames_traint['SalePrice'].values

x_test = ames_testt.iloc[:, 1:-1].values
y_test = ames_testt['SalePrice'].values

model = XGBClassifier()
model.fit(x_train, y_train)

y_pred = model.predict(x_test)
print(y_pred)
